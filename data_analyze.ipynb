# %%
import pandas as pd

# %%
path = "Для хакатона.xlsx"

# %%
general_infos = pd.read_excel(path, sheet_name='Общая информация', header=0)
publications = pd.read_excel(path, sheet_name='Публикации', header=0)
projects = pd.read_excel(path, sheet_name='Проекты', header=0)
events = pd.read_excel(path, sheet_name='Мероприятия', header=0)

# %%
general_infos.head()
# Out:
#    ИСУ   ФИО                                           ОБУЧЕНИЕ  \
# 0    1  Катя  студент, 2 курс, группа F42712, институт персп...
# 1    2  Лиза  студент, 2 курс, группа B42005c, центр приклад...
# 2    3  Маша  студент, 1 курс, группа U4126, факультет техно...
# 3    4  Галя  студент, 2 курс, группа K42402, факультет инфо...
# 4    5  Даша  студент, 4 курс, группа P34704, факультет прог...
#
#                                            ДОЛЖНОСТИ  \
# 0  инженер ( 0,25 ст.), [12440] лаборатория одноф...
# 1                                                NaN
# 2  менеджер ( 1,00 ст.), [695] центр организации ...
# 3  инженер ( 0,25 ст.), [622276] мегафакультет тр...
# 4  делопроизводитель ( 0,25 ст.), [922041] офис п...
#
#                                           ПОЛНОМОЧИЯ
# 0  выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 1     выпускник, ITMO.FAMILY, структура: ITMO.FAMILY
# 2  выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# ...

# %%
pd.DataFrame(general_infos.ДОЛЖНОСТИ.dropna().unique())
# Out:
#                                                    0
# 0  инженер ( 0,25 ст.), [12440] лаборатория одноф...
# 1  менеджер ( 1,00 ст.), [695] центр организации ...
# 2  инженер ( 0,25 ст.), [622276] мегафакультет тр...
# 3  делопроизводитель ( 0,25 ст.), [922041] офис п...
# 4  делопроизводитель ( 0,25 ст.), [922041] офис п...
# 5  инженер ( 0,25 ст.), [922010] химико-биологиче...
# 6  лаборант ( 0,25 ст.), [92133] проектный офис п...
# 7  лаборант ( 0,10 ст.), [244] центр изучения ино...

# %%
pd.DataFrame(general_infos.ПОЛНОМОЧИЯ.dropna().unique())
# Out:
#                                                     0
# 0   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 1      выпускник, ITMO.FAMILY, структура: ITMO.FAMILY
# 2   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 3   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 4   стажер, центр развития дополнительного образов...
# 5   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 6   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 7   выпускник, ITMO.FAMILY, структура: ITMO.FAMILY...
# 8   руководитель клуба, Клуб кураторов «Адаптер»  ...
# 9   член клуба, Клуб дизайна DesArm, структура: IT...
# 10  член клуба, Клуб настольных игр GEEKMO, структ...
# 11  руководитель клуба, ITMO Speaking Club, структ...

# %%
publications.head()
# Out:
#    ИСУ ТИП_ПУБЛИКАЦИИ                                    ВЫХОДНЫЕ_ДАННЫЕ  \
# 0    7         Статья  Беляев В.Е., Кузнецов Д.А. Влияние скорости ре...
# 1    7         Тезисы  Беляев В.Е., Кузнецов Д.А. Влияние скорости ре...
# 2    7         Тезисы  Belyaev V.E., Pomytkina A.V., Aliev T.A., Niki...
# 3    7         Статья  Masalovich M., Aliev T., Beliaev V.E., Pomytki...
# 4    7         Тезисы  Беляев В.Е., Пивень А.О., Алиев Т.А. Мультиэле...
#
#     ГОД ИНДЕКСИРОВАНИЕ_В_БД
# 0  2021                 NaN
# 1  2021                 NaN
# 2  2021                 NaN
# 3  2022                 NaN
# 4  2022                 NaN

# %%
pd.DataFrame(publications.ИСУ.dropna().unique())
# Out:
#     0
# 0   7
# 1   1
# 2   8
# 3   6
# 4   4
# 5   2
# 6   3
# 7  10

# %%
pd.DataFrame(publications.ТИП_ПУБЛИКАЦИИ.dropna().unique())
# Out:
#         0
# 0  Статья
# 1  Тезисы

# %%
pd.DataFrame(publications.ГОД.dropna().unique())
# Out:
#       0
# 0  2021
# 1  2022
# 2  2023
# 3  2019
# 4  2020

# %%
pd.DataFrame(publications.ИНДЕКСИРОВАНИЕ_В_БД.dropna().unique())
# Out:
#                         0
# 0                    РИНЦ
# 1  Scopus, Web of Science

# %%
projects.head()
# Out:
#    ИСУ  НОМЕР_ТЕМЫ ТИП_ПРОЕКТА  \
# 0    1      421241         НИР
# 1    1      620164   НИР-ПОИСК
# 2    1       12440         НИР
# 3   12      320356      Другие
# 4    4      622276      Другие
#
#                                         НАИМЕНОВАНИЕ  \
# 0          Разработка УФ-С фотодиода на основе Ga2O3
# 1  Методы искусственного интеллекта для киберфизи...
# 2  Исследование фундаментальных процессов генерац...
# 3  Всероссийская олимпиада студентов "Я - професс...
# 4  Веб-сервис автоматизированного нормоконтроля о...
#
#                                        ПОДРАЗДЕЛЕНИЕ     НАЧАЛО  ОКОНЧАНИЕ  \
# 0  [157] научно-исследовательский центр перспекти... 2021-05-01 2022-12-31
# 1  [773] мегафакультет компьютерных технологий и ... 2020-09-01 2023-06-30
# 2  [840] лаборатория однофотонных детекторов и ге... 2020-01-01 2024-12-31
# 3  [449] студенческое проектно-исследовательское ... 2020-01-01 2021-12-15
# ...

# %%
pd.DataFrame(projects.ТИП_ПРОЕКТА.dropna().unique())
# Out:
#            0
# 0        НИР
# 1  НИР-ПОИСК
# 2     Другие

# %%
pd.DataFrame(projects.РОЛЬ.dropna().unique())
# Out:
#           0
# 0  Участник

# %%
pd.DataFrame(projects.ЗАКАЗЧИК.dropna().unique())
# Out:
#                              0
# 0             Университет ИТМО
# 1           МИНОБРНАУКИ РОССИИ
# 2  АССОЦИАЦИЯ «Я-ПРОФЕССИОНАЛ»
# 3          ПАО "ГАЗПРОМ НЕФТЬ"

# %%
events.head()
# Out:
#    ИСУ                                       НАИМЕНОВАНИЕ  \
# 0    1   Пятьдесят вторая (LII) научная и учебно-метод...
# 1    1  Деятельность проекта &quot;Адаптер&quot;. Осен...
# 2    1  День открытых дверей Университета ИТМО для буд...
# 3    1                                   Startup Aquarium
# 4    1       Квест-игра &quot;Fotonics Horror Story&quot;
#
#                     СРОКИ   ГОД                   ТИП             РАНГ  \
# 0  31 Января - 03 Февраля  2023           Конференция  университетский
# 1  31 Августа - 31 Января  2018                Проект  университетский
# 2               27 Января  2019  День открытых дверей  университетский
# 3                  26 Мая  2023           Конференция        городской
# 4             25 Сентября  2019                 Квест    факультетский
#
#                         РОЛИ
# 0                   Участник
# 1                   Волонтер
# 2                   Волонтер
# 3  Ответственный исполнитель
# 4  Ответственный исполнитель

# %%
pd.DataFrame(events.ТИП.dropna().unique())
# Out:
#                              0
# 0                  Конференция
# 1                       Проект
# 2         День открытых дверей
# 3                        Квест
# 4                        Митап
# ..                         ...
# 59                    Интервью
# 60                      Юбилеи
# 61                       Финал
# 62  Публичное массовое зрелище
# 63                   Спектакль
#
# [64 rows x 1 columns]

# %%
pd.DataFrame(events.РАНГ.dropna().unique())
# Out:
#                  0
# 0  университетский
# 1        городской
# 2    факультетский
# 3    международный
# 4    всероссийский
# 5     межвузовский
# 6           прочее
# 7     региональный
# 8     общественный
# 9         районный

# %%
pd.DataFrame(events.РОЛИ.dropna().unique())
# Out:
#                                                 0
# 0                                        Участник
# 1                                        Волонтер
# 2                       Ответственный исполнитель
# 3                                     Организатор
# 4                       Волонтер, Пресс-секретарь
# 5                              Волонтер, Участник
# 6                             Главный организатор
# 7                              Волонтер, Волонтер
# 8                                Спикер, Участник
# 9                                Член оргкомитета
# 10                     Волонтер, Спикер, Участник
# 11                             Дизайнер, Участник
# 12                             Участник, Участник
# 13  Дизайнер, Ответственный исполнитель, Участник
# 14                                         Спикер
# 15            Ответственный исполнитель, Участник
# 16                          Организатор, Участник
# 17                     Член программного комитета
# ...

# %%
def aggregate_infos(id):
    pass
